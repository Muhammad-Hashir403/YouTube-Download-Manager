# %%
from google import genai

# Replace with your actual API key
API_KEY = "AIzaSyD8IKnBYqr2r19gbJ_6coIHQ7Duat6zAPY"

# Initialize the client
client = genai.Client(api_key=API_KEY)

# Upload the audio file
audio_file_path = "audioo.mp3" # Change this to your file path
uploaded_file = client.files.upload(file="audioo.mp3")

# Generate content from the uploaded audio
response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=["Generate a transcript of the speech.", uploaded_file]
)

# Print the generated response
print(response.text)
# Out:
# What is computer?

# %%
from google import genai

client = genai.Client(api_key="AIzaSyD8IKnBYqr2r19gbJ_6coIHQ7Duat6zAPY")
chat = client.chats.create(model="gemini-2.0-flash")

response = chat.send_message_stream("I have 2 dogs in my house.")
for chunk in response:
    print(chunk.text, end="")

response = chat.send_message_stream("How many paws are in my house?")
for chunk in response:
    print(chunk.text, end="")

for message in chat.get_history():
    print(f'role - {message.role}', end=": ")
    print(message.parts[0].text)
# Out:
# Okay, good to know! Is there anything specific you'd like to talk about regarding your dogs? For example:
#
# *   Do you want to tell me their names and breeds?
# *   Do you have any questions about dog care?
# *   Are you looking for advice on a particular dog-related issue?
#
# I'm here to listen and help if I can!
# Assuming your two dogs are normal and you and any other humans in the house have feet, there are:
#
# *   2 dogs * 4 paws/dog = 8 paws
#
# So there are **8** paws in your house.
# role - user: I have 2 dogs in my house.
# role - model: Okay
# role - model: , good to
# role - model:  know! Is there anything specific you'd like to talk about regarding your dogs
# role - model: ? For example:
#
# *   Do you want to tell me their names and
# role - model:  breeds?
# *   Do you have any questions about dog care?
# *   Are you looking for advice on a particular dog-related issue?
#
# I'm here
# role - model:  to listen and help if I can!
#
# ...

# %%
from google import genai

client = genai.Client(api_key="AIzaSyD8IKnBYqr2r19gbJ_6coIHQ7Duat6zAPY")

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=["How does AI work?"]
)
print(response.text)
# Out:
# Okay, let's break down how AI works, aiming for a clear and understandable explanation.  It's a broad topic, so we'll cover the key concepts and then touch on some specifics.
#
# **The Core Idea: Enabling Computers to Think (Sort Of)**
#
# At its heart, Artificial Intelligence (AI) is about creating computer systems that can perform tasks that typically require human intelligence.  These tasks might include:
#
# *   **Learning:** Acquiring information and rules for using it.
# *   **Reasoning:** Using rules to reach conclusions (deductive, inductive, abductive).
# *   **Problem-solving:** Finding solutions to complex issues.
# *   **Perception:** Understanding sensory input (vision, sound, etc.).
# *   **Language understanding:**  Interpreting and responding to human language.
# *   **Decision-making:** Choosing the best course of action from a set of possibilities.
#
# **How AI Achieves These Goals: Key Techniques**
#
# ...
